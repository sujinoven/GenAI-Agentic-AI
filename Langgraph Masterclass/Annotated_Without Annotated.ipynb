# %% [markdown]
# # **1. Without Annotated — Just a List of Messages**

# %%
from typing import TypedDict
from langchain_core.messages import HumanMessage, AIMessage
from langgraph.graph import StateGraph, START, END

class State(TypedDict):
    messages: list

def chatbot(state):
    return {"messages": [AIMessage(content="Hello! How can I help you?")]}

builder = StateGraph(State)

builder.add_node("chatbot", chatbot)

builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

graph = builder.compile()

result = graph.invoke({"messages": [HumanMessage(content="Hi")]})

print(result["messages"])
# Out:
# [AIMessage(content='Hello! How can I help you?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# # **2. With Annotated - With AnyMessages and add_messages**

# %%
from typing import Annotated, TypedDict
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langchain_core.messages import AnyMessage, HumanMessage,AIMessage

class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

def chatbot(state):
    return {"messages": [AIMessage(content="Hello! How can I help you?")]}

builder = StateGraph(State)

builder.add_node("chatbot", chatbot)

builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

graph = builder.compile()

result = graph.invoke({"messages": [HumanMessage(content="Hi")]})

print(result["messages"])
# Out:
# [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='2a4174ef-7ec4-4919-8a06-8eb296fa729e'), AIMessage(content='Hello! How can I help you?', additional_kwargs={}, response_metadata={}, id='2ffcc0e3-c0ee-408e-8dd9-5039422d2a9b', tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# # **THE END.**
